# %% [markdown]
# # Week 7: Natural language processing

# %% [markdown]
# The exercises today are about extracting high-level knowledge from text. We're still a long way from computers being able to give us insight as deep as that which we can aquire from manually reading text, but some the tools that you will use today get us a long way in understanding useful things about unreadibly large amount of text in comparatively little time. In the exercises today you will:
#
# * Create wordclouds
# * Extract sentiment from text
# * Construct a Bag of Words (BoW) matrix to represent how words are used about each faction in the Marvel dataset
# * Perform a TD-IDF transform to understand which words are important to different characters
#
# [**Feedback**](http://ulfaslak.com/vent)

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Part 1 (Extra): Wordcloud

# %% [markdown]
# Although they probably offer more buzz than usefulness, wordclouds are a fun way to get quick insight into which words are used in a corpus of text. In this section you will generate one.

# %% [markdown]
# >**Ex. 7.1.1**: To make a word cloud you need some more or less clean text. For each character extract as cleanly as you can, the text written on their wikipage. Since the wikidata is kind of messy, there are some things you should be aware of when extracting the text.
# * Exclude character names.
# * Exclude links.
# * Exclude numbers.
# * Set everything to lower case.
# * Do not include stopwords (use `nltk.corpus.stopwords.words("english")` to get a list of stopwords; install `nltk` to do this).
#
# >Cleaning doesn't have to be perfect and can be done in a many different ways, these are just some things to look out for.
#
# >Once you have extracted the text, create one long text string for all text written about heroes, another long text string for villains, and finally one for ambiguous characters. Using the code snippet below which shows how to plot a word cloud, plot the word clouds for each faction.
#
# >        text = "some cool text"
# >        wc = wordcloud.WordCloud(max_font_size=40).generate(text)
# >
# >        plt.figure()
# >        plt.imshow(wc, interpolation="bilinear")
# >        plt.axis("off")
# >        plt.show()
#
# > You have to import `matplotlib.pylab` and `wordcloud` to do this. You can install `wordcloud` with anaconda by typing into your console
#
# >        conda install -c conda-forge wordcloud
#
# >or
#
# >        pip install wordcloud
#
# >if you don't have Anaconda installed.

# %% [markdown]
# Helper function to get vector of words for a character. Make sure the path to your data is correct.

# %%
import re
import nltk

# Get a list of stopwords from nltk
stopwords = nltk.corpus.stopwords.words("english")

def get_clean_words(character_filename, faction):
    def _isnum(w):
        try:
            int(w)
            return True
        except ValueError:
            return False
        
    # Load her markup
    with open("/Users/clairemarie/Desktop/analysis/data/%s/%s" % (faction, character_filename)) as fp:
        markup = fp.read()

    # Remove table and external links
    markup_text = re.sub(r'\{\{[\s\S]*?\}\}', '', markup)

    # Remove category links
    markup_text = re.sub(r'\[\[Category.+\]\]', '', markup_text)

    # Set words to lowercase and remove them if they are stop words
    words = [w.lower() for w in re.findall('\w+', markup_text) if w.lower() not in stopwords]

    # Remove numbers
    words = [w for w in words if not _isnum(w)]

    return words

# Example
get_clean_words("Iron man.txt", "heroes")
# Out:
# ['iron',
#  'man',
#  'anthony',
#  'edward',
#  'tony',
#  'stark',
#  'fictional',
#  'superhero',
#  'appearing',
#  'american',
#  'comic',
#  'book',
#  'published',
#  'marvel',
#  'comics',
#  'character',
#  'co',
#  'created',
#  'writer',
#  'editor',
#  'stan',
#  'lee',
#  'developed',
#  'scripter',
#  'larry',
#  'lieber',
#  'designed',
#  'artists',
#  'heck',
#  'jack',
#  'kirby',
#  'character',
#  'made',
#  'first',
#  'appearance',
#  'tales',
#  'suspense',
#  'cover',
#  'date',
#  'march',
#  'received',
#  'title',
#  'iron',
#  'man',
#  'comic',
#  'book',
#  'iron',
#  'man',
#  'may',
#  'wealthy',
#  'american',
#  'business',
#  'magnate',
#  'playboy',
#  'lifestyle',
#  'playboy',
#  'ingenious',
#  'scientist',
#  'anthony',
#  'edward',
#  'tony',
#  'stark',
#  'suffers',
#  'severe',
#  'chest',
#  'injury',
#  'kidnapping',
#  'captors',
#  'attempt',
#  'force',
#  'build',
#  'weapon',
#  'mass',
#  'destruction',
#  'instead',
#  'creates',
#  'iron',
#  'man',
#  'armor',
#  'powered',
#  'suit',
#  'armor',
#  'save',
#  'life',
#  'escape',
#  'captivity',
#  'later',
#  'stark',
#  'develops',
#  'suit',
#  'adding',
#  'weapons',
#  'technological',
#  'devices',
#  'designed',
#  'company',
#  'stark',
#  'industries',
#  'uses',
#  'suit',
#  'successive',
#  'versions',
#  'protect',
#  'world',
#  'iron',
#  'man',
#  'although',
#  'first',
#  'concealing',
#  'true',
#  'identity',
#  'stark',
#  'eventually',
#  'declared',
#  'fact',
#  'iron',
#  'man',
#  'public',
#  'announcement',
#  'initially',
#  'iron',
#  'man',
#  'vehicle',
#  'stan',
#  'lee',
#  'explore',
#  'cold',
#  'war',
#  'themes',
#  'particularly',
#  'role',
#  'american',
#  'technology',
#  'industry',
#  'fight',
#  'communism',
#  'ref',
#  'name',
#  'lee',
#  'iron',
#  'ref',
#  'subsequent',
#  'imaginings',
#  'iron',
#  'man',
#  'transitioned',
#  'cold',
#  'war',
#  'motifs',
#  'contemporary',
#  'matters',
#  'time',
#  'ref',
#  'name',
#  'lee',
#  'iron',
#  'throughout',
#  'character',
#  'publication',
#  'history',
#  'iron',
#  'man',
#  'founding',
#  'member',
#  'superhero',
#  'team',
#  'avengers',
#  'comics',
#  'avengers',
#  'featured',
#  'several',
#  'incarnations',
#  'various',
#  'comic',
#  'book',
#  'series',
#  'iron',
#  'man',
#  'adapted',
#  'several',
#  'animated',
#  'tv',
#  'shows',
#  'films',
#  'tony',
#  'stark',
#  'marvel',
#  'cinematic',
#  'universe',
#  'marvel',
#  'cinematic',
#  'universe',
#  'character',
#  'portrayed',
#  'robert',
#  'downey',
#  'jr',
#  'live',
#  'action',
#  'film',
#  'iron',
#  'man',
#  'film',
#  'iron',
#  'man',
#  'critical',
#  'box',
#  'office',
#  'success',
#  'downey',
#  'received',
#  'much',
#  'acclaim',
#  'performance',
#  'reprised',
#  'role',
#  'cameo',
#  'incredible',
#  'hulk',
#  'film',
#  'incredible',
#  'hulk',
#  'two',
#  'iron',
#  'man',
#  'sequels',
#  'iron',
#  'man',
#  'iron',
#  'man',
#  'avengers',
#  'film',
#  'avengers',
#  'avengers',
#  'age',
#  'ultron',
#  'captain',
#  'america',
#  'civil',
#  'war',
#  'spider',
#  'man',
#  'homecoming',
#  'avengers',
#  'infinity',
#  'war',
#  'avengers',
#  'endgame',
#  'marvel',
#  'cinematic',
#  'universe',
#  'iron',
#  'man',
#  'ranked',
#  '12th',
#  'ign',
#  'top',
#  'comic',
#  'book',
#  'heroes',
#  'ref',
#  'name',
#  'igntop100',
#  'ref',
#  'third',
#  'list',
#  'top',
#  'avengers',
#  'ref',
#  'ref',
#  'publication',
#  'history',
#  'premiere',
#  'iron',
#  'man',
#  'marvel',
#  'comics',
#  'premiere',
#  'tales',
#  'suspense',
#  'cover',
#  'date',
#  'march',
#  'collaboration',
#  'among',
#  'editor',
#  'story',
#  'plotter',
#  'stan',
#  'lee',
#  'scripter',
#  'larry',
#  'lieber',
#  'story',
#  'artist',
#  'heck',
#  'cover',
#  'artist',
#  'character',
#  'designer',
#  'jack',
#  'kirby',
#  'ref',
#  'ref',
#  'lee',
#  'toying',
#  'idea',
#  'businessman',
#  'superhero',
#  'ref',
#  'name',
#  'origins',
#  'ref',
#  'wanted',
#  'create',
#  'quintessential',
#  'capitalist',
#  'character',
#  'would',
#  'go',
#  'spirit',
#  'times',
#  'marvel',
#  'readership',
#  'ref',
#  'name',
#  'excelsior',
#  'ref',
#  'lee',
#  'said',
#  'ref',
#  'set',
#  'make',
#  'new',
#  'character',
#  'wealthy',
#  'glamorous',
#  'ladies',
#  'man',
#  'one',
#  'secret',
#  'would',
#  'plague',
#  'torment',
#  'well',
#  'ref',
#  'name',
#  'origins',
#  'pt',
#  'lee',
#  'son',
#  'origins',
#  'marvel',
#  'comics',
#  'pp',
#  'ref',
#  'writer',
#  'gerry',
#  'conway',
#  'said',
#  'character',
#  'outside',
#  'invulnerable',
#  'mean',
#  'touched',
#  'inside',
#  'wounded',
#  'figure',
#  'stan',
#  'made',
#  'much',
#  'face',
#  'wound',
#  'know',
#  'heart',
#  'broken',
#  'know',
#  'literally',
#  'broken',
#  'metaphor',
#  'going',
#  'think',
#  'made',
#  'character',
#  'interesting',
#  'ref',
#  'name',
#  'imdvd',
#  'lee',
#  'based',
#  'playboy',
#  'looks',
#  'personality',
#  'howard',
#  'hughes',
#  'ref',
#  'name',
#  'maskarticle',
#  'ref',
#  'explaining',
#  'howard',
#  'hughes',
#  'one',
#  'colorful',
#  'men',
#  'time',
#  'inventor',
#  'adventurer',
#  'multi',
#  'billionaire',
#  'ladies',
#  'man',
#  'finally',
#  'nutcase',
#  'ref',
#  'lee',
#  'stan',
#  'december',
#  'stan',
#  'soapbox',
#  'bullpen',
#  'bulletins',
#  'marvel',
#  'comics',
#  'ref',
#  'without',
#  'crazy',
#  'howard',
#  'hughes',
#  'lee',
#  'said',
#  'ref',
#  'name',
#  'imdvd',
#  'lee',
#  'intended',
#  'write',
#  'story',
#  'ref',
#  'name',
#  'origins',
#  'pt',
#  'lee',
#  'son',
#  'origins',
#  'p',
#  'ref',
#  'minor',
#  'deadline',
#  'emergency',
#  'eventually',
#  'forced',
#  'hand',
#  'premiere',
#  'issue',
#  'lieber',
#  'fleshed',
#  'story',
#  'ref',
#  'name',
#  'origins',
#  'pt',
#  'art',
#  'split',
#  'kirby',
#  'heck',
#  'designed',
#  'costume',
#  'heck',
#  'said',
#  'kirby',
#  'cover',
#  'covers',
#  'always',
#  'done',
#  'first',
#  'created',
#  'look',
#  'characters',
#  'like',
#  'tony',
#  'stark',
#  'secretary',
#  'pepper',
#  'potts',
#  'ref',
#  'ref',
#  'interview',
#  'asked',
#  'specific',
#  'model',
#  'tony',
#  'stark',
#  'characters',
#  'heck',
#  'replied',
#  'would',
#  'thinking',
#  'along',
#  'lines',
#  'characters',
#  'like',
#  'would',
#  'kind',
#  'characters',
#  'alex',
#  'toth',
#  'liked',
#  'errol',
#  'flynn',
#  'type',
#  'ref',
#  'ref',
#  'iron',
#  'man',
#  'first',
#  'appeared',
#  'page',
#  'stories',
#  'tales',
#  'suspense',
#  'featured',
#  'anthology',
#  'science',
#  'fiction',
#  'supernatural',
#  'stories',
#  'character',
#  'original',
#  'costume',
#  'bulky',
#  'gray',
#  'armored',
#  'suit',
#  'replaced',
#  'golden',
#  'version',
#  'second',
#  'story',
#  'issue',
#  'april',
#  'redesigned',
#  'sleeker',
#  'red',
#  'golden',
#  'armor',
#  'issue',
#  'dec',
#  'issue',
#  'interior',
#  'artist',
#  'steve',
#  'ditko',
#  'although',
#  'kirby',
#  'drew',
#  'cover',
#  'heck',
#  'recalled',
#  'second',
#  'costume',
#  'red',
#  'yellow',
#  'one',
#  'designed',
#  'steve',
#  'ditko',
#  'found',
#  'easier',
#  'drawing',
#  'bulky',
#  'old',
#  'thing',
#  'earlier',
#  'design',
#  'robot',
#  'looking',
#  'one',
#  'kirbyish',
#  'ref',
#  'name',
#  'featurep18',
#  'heck',
#  'quoted',
#  'ref',
#  'premiere',
#  'iron',
#  'man',
#  'anti',
#  'communism',
#  'anti',
#  'communist',
#  'hero',
#  'defeating',
#  'various',
#  'vietnamese',
#  'agents',
#  'lee',
#  'later',
#  'regretted',
#  'early',
#  'focus',
#  'ref',
#  'name',
#  'origins',
#  'ref',
#  'name',
#  'nation',
#  'ref',
#  'throughout',
#  'character',
#  'comic',
#  'book',
#  'series',
#  'technological',
#  'advancement',
#  'national',
#  'security',
#  'national',
#  'defense',
#  'constant',
#  'themes',
#  'iron',
#  'man',
#  'later',
#  'issues',
#  'developed',
#  'stark',
#  'complex',
#  'vulnerable',
#  'character',
#  'depicted',
#  'battle',
#  'alcoholism',
#  'demon',
#  'bottle',
#  'storyline',
#  'personal',
#  'difficulties',
#  'issue',
#  'nov',
#  'final',
#  'issue',
#  'march',
#  'anthological',
#  'science',
#  'fiction',
#  'backup',
#  'stories',
#  'tales',
#  'suspense',
#  'replaced',
#  'feature',
#  'starring',
#  'superhero',
#  'captain',
#  'america',
#  'lee',
#  'heck',
#  'introduced',
#  'several',
#  'adversaries',
#  'character',
#  'including',
#  'mandarin',
#  'comics',
#  'mandarin',
#  'issue',
#  'feb',
#  'ref',
#  'defalco',
#  '1960s',
#  'gilbert',
#  'p',
#  'following',
#  'tradition',
#  'sax',
#  'rohmer',
#  'fu',
#  'manchu',
#  'atlas',
#  'yellow',
#  'claw',
#  'mandarin',
#  'first',
#  'appeared',
#  'tales',
#  'suspense',
#  'story',
#  'written',
#  'stan',
#  'lee',
#  'illustrated',
#  'heck',
#  'ref',
#  'black',
#  'widow',
#  'natasha',
#  'romanova',
#  'black',
#  'widow',
#  'april',
#  'ref',
#  'defalco',
#  '1960s',
#  'gilbert',
#  'p',
#  'black',
#  'widow',
#  'russian',
#  'spy',
#  'assigned',
#  'capture',
#  'american',
#  'industrialist',
#  'tony',
#  'stark',
#  'story',
#  'plotted',
#  'stan',
#  'lee',
#  'written',
#  'rico',
#  'drawn',
#  'heck',
#  'ref',
#  'hawkeye',
#  'comics',
#  'hawkeye',
#  'five',
#  'issues',
#  'later',
#  'ref',
#  'defalco',
#  '1960s',
#  'gilbert',
#  'p',
#  'case',
#  'mistaken',
#  'identity',
#  'led',
#  'police',
#  'assume',
#  'hawkeye',
#  'part',
#  'criminal',
#  'gang',
#  'black',
#  'widow',
#  'saved',
#  'capture',
#  'also',
#  'tricked',
#  'fighting',
#  'iron',
#  'man',
#  'ref',
#  'lee',
#  'said',
#  'comic',
#  'books',
#  'published',
#  'marvel',
#  'got',
#  'fan',
#  'mail',
#  'iron',
#  'man',
#  'women',
#  'females',
#  'title',
#  'get',
#  'much',
#  'fan',
#  'mail',
#  'girls',
#  'whenever',
#  'letter',
#  'usually',
#  'addressed',
#  'iron',
#  'man',
#  'ref',
#  'name',
#  'imdvd',
#  'lee',
#  'kirby',
#  'included',
#  'iron',
#  'man',
#  'avengers',
#  'comic',
#  'book',
#  'avengers',
#  'sept',
#  'founding',
#  'member',
#  'superhero',
#  'team',
#  'character',
#  'since',
#  'appeared',
#  'every',
#  'subsequent',
#  'volume',
#  'series',
#  'writers',
#  'updated',
#  'war',
#  'locale',
#  'stark',
#  'injured',
#  'original',
#  'story',
#  'vietnam',
#  'war',
#  '1990s',
#  'updated',
#  'first',
#  'gulf',
#  'war',
#  'ref',
#  'name',
#  'emerging',
#  'pop',
#  'ref',
#  '2000s',
#  'updated',
#  'war',
#  'afghanistan',
#  'present',
#  'war',
#  'afghanistan',
#  'stark',
#  'time',
#  'asian',
#  'nobel',
#  'prize',
#  'winning',
#  'scientist',
#  'ho',
#  'yinsen',
#  'consistent',
#  'nearly',
#  'incarnations',
#  'iron',
#  'man',
#  'origin',
#  'depicting',
#  'stark',
#  'yinsen',
#  'building',
#  'original',
#  'armor',
#  'together',
#  'one',
#  'exception',
#  'direct',
#  'dvd',
#  'animated',
#  'feature',
#  'film',
#  'invincible',
#  'iron',
#  'man',
#  'film',
#  'invincible',
#  'iron',
#  'man',
#  'armor',
#  'stark',
#  'uses',
#  'escape',
#  'captors',
#  'first',
#  'iron',
#  'man',
#  'suit',
#  'themes',
#  'original',
#  'iron',
#  'man',
#  'title',
#  'explored',
#  'cold',
#  'war',
#  'themes',
#  'stan',
#  'lee',
#  'projects',
#  'early',
#  'years',
#  'marvel',
#  'comics',
#  'fantastic',
#  'four',
#  'incredible',
#  'hulk',
#  'comic',
#  'book',
#  'incredible',
#  'hulk',
#  'respectively',
#  'focused',
#  'american',
#  'domestic',
#  'government',
#  'responses',
#  'communist',
#  'threat',
#  'iron',
#  'man',
#  'explored',
#  'industry',
#  'role',
#  'struggle',
#  'tony',
#  'stark',
#  'real',
#  'life',
#  'model',
#  'howard',
#  'hughes',
#  'significant',
#  'defense',
#  'contractor',
#  'developed',
#  'new',
#  'weapons',
#  'technologies',
#  'hughes',
#  'icon',
#  'american',
#  'individualism',
#  'burdens',
#  'fame',
#  'ref',
#  'name',
#  'journalofpopculture',
#  'ref',
#  'historian',
#  'robert',
#  'genter',
#  'journal',
#  'popular',
#  'culture',
#  'writes',
#  'tony',
#  'stark',
#  'specifically',
#  'presents',
#  'idealized',
#  'portrait',
#  'american',
#  'inventor',
#  'earlier',
#  'decades',
#  'seen',
#  'important',
#  'technological',
#  'innovations',
#  'come',
#  'famous',
#  'individuals',
#  'e',
#  'g',
#  'nikola',
#  'tesla',
#  'thomas',
#  'edison',
#  'alexander',
#  'graham',
#  'bell',
#  'wright',
#  'brothers',
#  '1960s',
#  'saw',
#  'new',
#  'technologies',
#  'including',
#  'weapons',
#  'developed',
#  'mainly',
#  'research',
#  'teams',
#  'corporations',
#  'result',
#  'little',
#  'room',
#  'remained',
#  'inventor',
#  'wanted',
#  'credit',
#  'creative',
#  'economic',
#  'control',
#  'creations',
#  'issues',
#  'entrepreneurial',
#  'autonomy',
#  ...]

# %% [markdown]
# ### Part 2: Sentiment analysis

# %% [markdown]
# Often you don't have time to read some text, but you need to know something about whether it positively or negatively toned. Enter *Sentiment Analysis*. The point of this exercise is to extract the sentiment of text on your heroes, villains and ambiguous characters and figure out whether Wikipedia is biased towards writing in a certain tone towards a certain kind of characters.

# %% [markdown]
# >**Ex. 7.2.1**: For each of the three character classes, compute the sentiment scores across wikipedia articles so that you can produce three histograms (one for each class) with sentiment scores. You can use the text strings you generated in the previous exercise. We will cheat a bit and use a library that does the scoring for us. Install `afinn` using `conda` or `pip` and extract the sentiment with that module. There's an example of how to use it on the library's [PyPi repository](https://pypi.python.org/pypi/afinn).

# %%
#get partners graph         
import re, os
import matplotlib.pyplot as plt
hero_text = []
ambig_text = []
vill_text = []

h = '/Users/clairemarie/Desktop/analysis/data/heroes'
v = '/Users/clairemarie/Desktop/analysis/data/villains'
a = '/Users/clairemarie/Desktop/analysis/data/ambiguous'
folders = [h,v,a]
failed = []
for f in folders:
    for filename in os.listdir(f):
        this = []
        if(f == h):
            this = get_clean_words(filename, "heroes")
            hero_text.append(this)
        if(f == a):
            this = get_clean_words(filename, "ambiguous")
            ambig_text.append(this)
        if(f == v):
            this = get_clean_words(filename, "villains")
            vill_text.append(this)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-a772e0455a4e> in <module>
#      12 failed = []
#      13 for f in folders:
# ---> 14     for filename in os.listdir(f):
#      15         this = []
#      16         if(f == h):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/clairemarie/Desktop/analysis/data/heroes'

# %%
from afinn import Afinn
afinn = Afinn()
afinn.score('This is utterly excellent!')

heroes_score = []
vill_score = []
ambig_score = []

h = '/Users/clairemarie/Desktop/analysis/data/heroes'
v = '/Users/clairemarie/Desktop/analysis/data/villains'
a = '/Users/clairemarie/Desktop/analysis/data/ambiguous'
for filename in os.listdir(h):
    fileroute = '/Users/clairemarie/Desktop/analysis/data/heroes/' + filename 
    f = open(fileroute, 'r')
    string = ""
    for line in f:
        string = string + line
    score = afinn.score(string)
    heroes_score.append(score)

for filename in os.listdir(v):
    fileroute = '/Users/clairemarie/Desktop/analysis/data/villains/' + filename 
    f = open(fileroute, 'r')
    string = ""
    for line in f:
        string = string + line
    score = afinn.score(string)
    vill_score.append(score)

for filename in os.listdir(a):
    fileroute = '/Users/clairemarie/Desktop/analysis/data/ambiguous/' + filename 
    f = open(fileroute, 'r')
    string = ""
    for line in f:
        string = string + line
    score = afinn.score(string)
    ambig_score.append(score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-8c6b001fda3d> in <module>
#      10 v = '/Users/clairemarie/Desktop/analysis/data/villains'
#      11 a = '/Users/clairemarie/Desktop/analysis/data/ambiguous'
# ---> 12 for filename in os.listdir(h):
#      13     fileroute = '/Users/clairemarie/Desktop/analysis/data/heroes/' + filename
#      14     f = open(fileroute, 'r')
#
# NameError: name 'os' is not defined

# %%
plt.hist(heroes_score)
plt.title("Heroes Afinn Scores")
plt.show()

# %%
plt.hist(vill_score)
plt.title("Villains Afinn Scores")
plt.show()

# %%
plt.hist(ambig_score)
plt.title("Ambiguous Afinn Scores")
plt.show()

# %% [markdown]
# ### Part 3: Bag of Words matrix

# %% [markdown]
# Intuitively, "Bag of Words" means breaking up a document into words and throwing them into a bag. And that's very close to the truth! In week 5 you constructed a "team-affiliations" matrix which had a row for each character and a column for each team. If the character was on a given team there would be a one for that character row at that team column, if not there would be a zero. The BoW is the same, only now, rather than teams, your columns are individual words that a character's wikipage might contain, and the numbers represent how many times those words appear.
# <img src="http://ulfaslak.com/computational_analysis_of_big_data/exer_figures/example_bow.png" width="400"/>
# BoW's are pretty large and sparse (mostly contain zero's) matrices, but they are extremely useful because they allow us to use linear algebra to do things like PCA, classification, etc..

# %% [markdown]
# >**Ex. 7.3.1**: Create a bag of words matrix that contains all your characters. Maintain also a target array, so you know whether a row corresponds to a hero or a villain. Do not include stopwords like "is", "a", etc. (get list of stopwords from `nltk.corpus.stopwords.words("english")`). Also, do not include words that only appear for one character.
# 1. How many different words are in your vocabulary/columns are in your matrix?
# 2. Print the 10 most used words, and the 10 least used words, along with their usage count.
# 3. Plot the distribution of how many times words are used.
#
# >*Hint: Since you already extracted lists of words for each faction in Ex. 7.1.1, you can use these to figure out what the total vocabulary of words used in your dataset is. You can "clean up" this vocabulary by a number of tricks. For example, there are tools for *stemming* words to remove grammar so that e.g. 'cat' and 'cats' both become 'cat', but that's all up to you whether you wanna go that deep.*

# %%
import numpy as np
bow = []
total_words = []
texts = [ambig_text, hero_text, vill_text]
for t in texts:
    for char in t:
        char_count = [0] * 50000
        
        for word in char:
            if(word not in total_words):
                total_words.append(word)
            for i in range(0,len(total_words)):
                try:
                    if(total_words[i] == word):
                        char_count[i] = char_count[i] + 1
                except:
                    print(i)
    bow.append(char_count)
# Out:
# 13907
# 23236
# 24774
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-bdad80c3ab68> in <module>()
#      10             if(word not in total_words):
#      11                 total_words.append(word)
# ---> 12             for i in range(0,len(total_words)):
#      13                 try:
#      14                     if(total_words[i] == word):
#
# KeyboardInterrupt:

# %%
for sentence in allsentences:
    bag_vector = numpy.zeros(len(vocab))
    for w in words:
        for i,word in enumerate(vocab):
            if word == w: 
                bag_vector[i] += 1
                    
    print("{0}\n{1}\n".format(sentence,numpy.array(bag_vector)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-3aece448465d> in <module>()
#       1
#       2
# ----> 3 for sentence in allsentences:
#       4     bag_vector = numpy.zeros(len(vocab))
#       5     for w in words:
#
# NameError: name 'allsentences' is not defined

# %% [markdown]
# > **Ex. 7.3.EXTRA**: Plot the first two components of the PCA transform of your BoW matrix. See anything interesting?

# %% [markdown]
# > **Ex. 7.3.EXTRA**: Create a classifier that predicts if a character is a hero or a villain from the words used on their page. Report its 10-fold cross validation accuracy.

# %% [markdown]
# ### Part 4: TF-IDF

# %% [markdown]
# You didn't just make that BoW matrix to count simple things. We are interested in knowing how (or if) words are used differently across characters, and the best way to do that is to used something called a Term Frequency - Inverse Document Frequency (TF-IDF) transformation. You can read about it [on Wikipedia](https://en.wikipedia.org/wiki/Tf%E2%80%93idf), but the gist is that it reflects how important each word is to each document (a document in this case being a faction).
#
# It works in two steps:
# * (1 - TF) you normalize over the frequency of each word in each document, so that rows sum to 1. Every row is now a probability distribution (a pmf to be exact) that gives the "term frequency" in each document.
# * (2 - IDF) you weigh the TF by the inverse document frequency, which measures how unique a word to specific documents. For example, the word "the" will be frequently used in every document (high TF) but we know it's not very special because it's used in all documents so the inverse document frequency is low, yielding a vanishing TF-IDF score for "the" in all documents.

# %% [markdown]
# >**Ex. 7.4.1**: Use any tool you like (you can do it manually, it's straight forward if you understand the method), to perform a TF-IDF transform on your BoW matrix from Ex. 7.3.1. The result should be a matrix of the same shape as the BoW, but with different values inside.
# 1. Explain what these values mean.
# 2. For the top three most written about characters in each class (so 9 in total), print out each of their 10 highest scoring words. Comment on any differences you observe in the type of words being used in different classes.

# %% [markdown]
# >**Ex. 7.4.2**: Import `from sklearn.manifold import TSNE` and transform the BoW matrix into a lower-dimensional space. Plot the points in this space.
# >
# >*Hint: You can simply do `X_tsne = TSNE(n_components=2).fit_transform(X_BoW)` and then plot the 0th and 1st axis of `X_tsne` against each other. If there are clusters of words use in the data, this plot will show them. You can make this even cooler by coloring the scattered points by their class.*
